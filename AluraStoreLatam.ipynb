# %% [markdown]
# <a href="https://colab.research.google.com/github/Gloria-Mar20/Challenge-Allura-Store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# Se hace la suma de todas las ventas que se hicieron en cada tienda para ver el total general

# %%
sum_total1= tienda['Precio'].sum()
sum_total2= tienda2['Precio'].sum()
sum_total3= tienda3['Precio'].sum()
sum_total4= tienda4['Precio'].sum()

# %%
#muestra de resultados
print(f' El ingresos total de la tienda 1 es {sum_total1:,.2f}')
print(f' El ingresos total de la tienda 2 es {sum_total2:,.2f}')
print(f' El ingresos total de la tienda 3 es {sum_total3:,.2f}')
print(f' El ingresos total de la tienda 4 es {sum_total4:,.2f}')
# Out:
#  El ingresos total de la tienda 1 es 1,150,880,400.00
#  El ingresos total de la tienda 2 es 1,116,343,500.00
#  El ingresos total de la tienda 3 es 1,098,019,600.00
#  El ingresos total de la tienda 4 es 1,038,375,700.00

# %% [markdown]
# ###La Tienda con mayor numero de facuracion es la **Tienda 1** con un valor de **$1,150,880,400.00**

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# Se calcula la antidad de productos vendidos por categoria en cada tienda

# %%
ventas_categoria1 = tienda['Categoría del Producto'].value_counts()
ventas_categoria2 = tienda2['Categoría del Producto'].value_counts()
ventas_categoria3 = tienda3['Categoría del Producto'].value_counts()
ventas_categoria4 = tienda4['Categoría del Producto'].value_counts()

# %%
#muestra de resultados
print(f'Las ventas por categoría de la tienda 1 son: \n\n {ventas_categoria1}\n\n')
print(f'Las ventas por categoría de la tienda 2 son: \n\n {ventas_categoria2}\n\n')
print(f'Las ventas por categoría de la tienda 3 son: \n\n {ventas_categoria3}\n\n')
print(f'Las ventas por categoría de la tienda 4 son: \n\n {ventas_categoria4}\n\n')
# Out:
# Las ventas por categoría de la tienda 1 son:
#
#  Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
#
# Las ventas por categoría de la tienda 2 son:
#
#  Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
#
# Las ventas por categoría de la tienda 3 son:
#
#  Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# ...

# %% [markdown]
# Se mostrara cual es la categoria mas vendida por tienda y su respectivo total

# %%
#calculo de las ventas por categoria
ventas_por_categoria = tienda.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria2 = tienda2.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria3 = tienda3.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria4 = tienda4.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)

#se agregan las comas a los numeros
ventas_por_categoria['Precio'] = ventas_por_categoria['Precio'].apply(lambda x: f"{x:,.2f}")
ventas_por_categoria2['Precio'] = ventas_por_categoria2['Precio'].apply(lambda x: f"{x:,.2f}")
ventas_por_categoria3['Precio'] = ventas_por_categoria3['Precio'].apply(lambda x: f"{x:,.2f}")
ventas_por_categoria4['Precio'] = ventas_por_categoria4['Precio'].apply(lambda x: f"{x:,.2f}")

#muestra de resultados
print(f'Las categorias de la Tienda 1 mas vendidas son\n {ventas_por_categoria}\n')
print(f'Las categorias de la Tienda 2 mas vendidas son\n {ventas_por_categoria2}\n')
print(f'Las categorias de la Tienda 3 mas vendidas son\n {ventas_por_categoria3}\n')
print(f'Las categorias de la Tienda 4 mas vendidas son\n {ventas_por_categoria4}\n')
# Out:
# Las categorias de la Tienda 1 mas vendidas son
#                                   Precio
# Categoría del Producto
# Electrónicos             429,493,500.00
# Electrodomésticos        363,685,200.00
# Muebles                  187,633,700.00
# Instrumentos musicales    91,299,000.00
# Deportes y diversión      39,290,000.00
# Juguetes                  17,995,700.00
# Artículos para el hogar   12,698,400.00
# Libros                     8,784,900.00
#
# Las categorias de la Tienda 2 mas vendidas son
#                                   Precio
# Categoría del Producto
# Electrónicos             410,831,100.00
# Electrodomésticos        348,567,800.00
# Muebles                  176,426,300.00
# Instrumentos musicales   104,990,300.00
# Deportes y diversión      34,744,500.00
# Juguetes                  15,945,400.00
# Artículos para el hogar   14,746,900.00
# Libros                    10,091,200.00
#
# Las categorias de la Tienda 3 mas vendidas son
# ...

# %% [markdown]
# ###Las categorias mas vendidas en todas las tiendas fueron **Muebles y Electronicos.**

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# Calculamos la calificación promedio por tienda, para conocer la satisfacción del cliente con los productos vendidos

# %%
calificacion_promedio1 = tienda['Calificación'].mean()
calificacion_promedio2 = tienda2['Calificación'].mean()
calificacion_promedio3 = tienda3['Calificación'].mean()
calificacion_promedio4 = tienda4['Calificación'].mean()

#Muestra de resultados
print(f'La calificación promedio de la tienda 1 es {calificacion_promedio1:,.2f}')
print(f'La calificación promedio de la tienda 2 es {calificacion_promedio2:,.2f}')
print(f'La calificación promedio de la tienda 3 es {calificacion_promedio3:,.2f}')
print(f'La calificación promedio de la tienda 4 es {calificacion_promedio4:,.2f}')
# Out:
# La calificación promedio de la tienda 1 es 3.98
# La calificación promedio de la tienda 2 es 4.04
# La calificación promedio de la tienda 3 es 4.05
# La calificación promedio de la tienda 4 es 4.00

# %% [markdown]
# ###La tienda con mejor calificación es la **Tienda 3** con una calificacion promedio de **4.05**

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def Productos_mas_menos_vendidos(data):
  #Agrupamos por productos y sumamos la facturación
  ventas_por_producto = data.groupby('Producto')['Precio'].sum().sort_values(ascending=False)

  #Obtenemos el producto con mayor facturación
  producto_mas_vendido = ventas_por_producto.idxmax(), ventas_por_producto.max()

  #Obtenemos el producto menos vendido
  producto_menos_vendido = ventas_por_producto.idxmin(), ventas_por_producto.min()

  return producto_mas_vendido, producto_menos_vendido

  #Muestra de resultados
  #print(f'El producto mas vendido es {producto_mas_vendido[0]} con una facturación de {producto_mas_vendido[1]:,.2f}')

# %%
#Calculo de productos mas vendidos y menos vendidos por tienda
mas_menos_tienda = Productos_mas_menos_vendidos(tienda)
mas_menos_tienda2 = Productos_mas_menos_vendidos(tienda2)
mas_menos_tienda3 = Productos_mas_menos_vendidos(tienda3)
mas_menos_tienda4 = Productos_mas_menos_vendidos(tienda4)

#Muestra de resultados
print(f'El producto mas vendido de la tienda 1 es {mas_menos_tienda[0][0]} con una facturación de {mas_menos_tienda[0][1]:,.2f}')
print(f'El producto menos vendido de la tienda 1 es {mas_menos_tienda[1][0]} con una facturación de {mas_menos_tienda[1][1]:,.2f}\n')
print(f'El producto mas vendido de la tienda 2 es {mas_menos_tienda2[0][0]} con una facturación de {mas_menos_tienda2[0][1]:,.2f}')
print(f'El producto menos vendido de la tienda 2 es {mas_menos_tienda2[1][0]} con una facturación de {mas_menos_tienda2[1][1]:,.2f}\n')
print(f'El producto mas vendido de la tienda 3 es {mas_menos_tienda3[0][0]} con una facturación de {mas_menos_tienda3[0][1]:,.2f}')
print(f'El producto menos vendido de la tienda 3 es {mas_menos_tienda3[1][0]} con una facturación de {mas_menos_tienda3[1][1]:,.2f}\n')
print(f'El producto mas vendido de la tienda 4 es {mas_menos_tienda4[0][0]} con una facturación de {mas_menos_tienda4[0][1]:,.2f}')
print(f'El producto menos vendido de la tienda 4 es {mas_menos_tienda4[1][0]} con una facturación de {mas_menos_tienda4[1][1]:,.2f}\n')
# Out:
# El producto mas vendido de la tienda 1 es TV LED UHD 4K con una facturación de 142,150,200.00
# El producto menos vendido de la tienda 1 es Cuerda para saltar con una facturación de 652,800.00
#
# El producto mas vendido de la tienda 2 es Iphone 15 con una facturación de 113,225,800.00
# El producto menos vendido de la tienda 2 es Cubo mágico 8x8 con una facturación de 643,600.00
#
# El producto mas vendido de la tienda 3 es Refrigerador con una facturación de 99,889,700.00
# El producto menos vendido de la tienda 3 es Cubo mágico 8x8 con una facturación de 640,400.00
#
# El producto mas vendido de la tienda 4 es Iphone 15 con una facturación de 96,697,500.00
# El producto menos vendido de la tienda 4 es Cuerda para saltar con una facturación de 704,800.00

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# Calculamos el costo de envio promedio por tienda

# %%
def envio_promedio(data):
  #Calculamos el costo promedio por envio
  envio_promedio = data['Costo de envío'].mean()
  return envio_promedio

# %%
# Calculamos elenvi promedo por cada tienda
envio_promedio_tienda1 = envio_promedio(tienda)
envio_promedio_tienda2 = envio_promedio(tienda2)
envio_promedio_tienda3 = envio_promedio(tienda3)
envio_promedio_tienda4 = envio_promedio(tienda4)

#Muestra de resultados
print(f'El costo de envio promedio de la tienda 1 es {envio_promedio_tienda1:,.2f}')
print(f'El costo de envio promedio de la tienda 2 es {envio_promedio_tienda2:,.2f}')
print(f'El costo de envio promedio de la tienda 3 es {envio_promedio_tienda3:,.2f}')
print(f'El costo de envio promedio de la tienda 4 es {envio_promedio_tienda4:,.2f}')
# Out:
# El costo de envio promedio de la tienda 1 es 26,018.61
# El costo de envio promedio de la tienda 2 es 25,216.24
# El costo de envio promedio de la tienda 3 es 24,805.68
# El costo de envio promedio de la tienda 4 es 23,459.46

# %% [markdown]
# #6. Graficos

# %% [markdown]
# ##Instalación de matplot y librerias

# %%
pip install matplotlib seaborn

# %%
#importamos libreriaspara poder hacer llos graficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Grafico 1 Ingreso por tienda

# %%
suma_total_tienda1 = 1150880400.0
suma_total_tienda2 = 1116343500.0
suma_total_tienda3 = 1098019600.0
suma_total_tienda4 = 1038375700.0

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
totales = [suma_total_tienda1, suma_total_tienda2, suma_total_tienda3, suma_total_tienda4]

fig_ingreso = plt.figure(figsize=(12, 7))
plt.bar(tiendas, totales)

plt.title("Valor total de ventas por tienda")
plt.xlabel("Tienda")
plt.ylabel("Suma total (Precio)")
plt.grid(axis="y", linestyle="--", alpha=0.5)


for i, valor in enumerate(totales):
    plt.text(i, valor, f"{valor:,.0f}", ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##Grafico 2 Ventas por categoria

# %%
total_categorias = (
    ventas_categoria1
    .add(ventas_categoria2, fill_value=0)
    .add(ventas_categoria3, fill_value=0)
    .add(ventas_categoria4, fill_value=0)
)

total_categorias = total_categorias.sort_values(ascending=False)

fig_ventas = plt.figure(figsize=(10, 10))
plt.pie(
    total_categorias.values,
    labels=total_categorias.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Distribución total de ventas por categoría de las Tienda 1,2,3,4")
plt.axis("equal")
plt.show()

# %% [markdown]
# ##Grafico 3 Costos de envio por tienda

# %%
import matplotlib.pyplot as plt

envio_promedio_tienda1 = 26018.61
envio_promedio_tienda2 = 25216.24
envio_promedio_tienda3 = 24805.68
envio_promedio_tienda4 = 23459.46

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
totales = [envio_promedio_tienda1, envio_promedio_tienda2, envio_promedio_tienda3, envio_promedio_tienda4]

# Colores para cada barra
colores = ["#4A90E2", "#50E3C2", "#F5A623", "#D0021B"]

fig_envios = plt.figure(figsize=(12, 7))

# Gráfico de barras horizontales
plt.scatter(tiendas, totales, s=200, color=colores, edgecolors="black")

plt.title("Envío promedio por tienda")
plt.xlabel("Tienda")
plt.ylabel("Valor Total")
plt.grid(axis="y", linestyle="--", alpha=0.5)

# Etiquetas encima de cada punto
for i, valor in enumerate(totales):
    plt.text(i, valor + 200, f"{valor:,.0f}", ha='center')

plt.show()

# %% [markdown]
# ###

# %% [markdown]
# # 7. Análisis del desempeño geográfico

# %% [markdown]
# En este análisis exploraremos las coordenadas geográficas presentes en los datos de ventas. Usando las columnas lat y lon, realizaremos visualizaciones que nos permitirán identificar patrones espaciales, concentraciones de ventas y posibles diferencias en el rendimiento según la ubicación.
#
# El objetivo de este desafío es:
#
# * Mapear las ventas de cada tienda utilizando latitud y longitud.
# * Generar gráficos de dispersión y mapas de calor (Heatmaps).
# * Detectar regiones donde las ventas se concentran o disminuyen.
# * Analizar si alguna tienda presenta un rendimiento superior según su ubicación geográfica.

# %%
tienda['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

df_geo = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

df_geo[['Tienda', 'lat', 'lon']].head()
# Out:
#      Tienda       lat       lon
# 0  Tienda 1   4.60971 -74.08175
# 1  Tienda 1   6.25184 -75.56359
# 2  Tienda 1  10.39972 -75.51444
# 3  Tienda 1   3.43722 -76.52250
# 4  Tienda 1   6.25184 -75.56359

# %%
#Grafica de la distribucion geografica de las ventas por tienda
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_geo, x='lon', y='lat', hue='Tienda', s=40)
plt.title("Distribución geográfica de las ventas por tienda")
plt.xlabel("Longitud (lon)")
plt.ylabel("Latitud (lat)")
plt.legend(title="Tienda")
plt.show()

# %%
#Mapa de calor de concentración de ventas
plt.figure(figsize=(8,6))
sns.kdeplot(
    data=df_geo,
    x='lon',
    y='lat',
    fill=True,
    thresh=0.05,
    levels=50
)
plt.title("Mapa de calor de concentración de ventas")
plt.xlabel("Longitud (lon)")
plt.ylabel("Latitud (lat)")
plt.show()

# %%
#Grafica de Comparación geográfica del rendimiento por tienda
plt.figure(figsize=(10,8))
sns.kdeplot(
    data=df_geo,
    x='lon',
    y='lat',
    hue='Tienda',
    fill=True,
    alpha=0.4
)
plt.title("Comparación geográfica del rendimiento por tienda")
plt.xlabel("Longitud (lon)")
plt.ylabel("Latitud (lat)")
plt.show()

# %% [markdown]
# **Resultados del análisis**
# 1. Regiones de concentración o disminución de ventas
# * Los mapas de calor muestran claramente que ciertas zonas tienen una alta  venta, mientras que otras presentan baja actividad.
# * Las áreas de alta concentración pueden representar zonas estratégicas donde la marca tiene mayor demanda.
# * Las regiones con menor densidad pueden indicar oportunidades de crecimiento.
# 2. Rendimiento geográfico por tienda
# * Al comparar la distribución geográfica de las ventas por tienda, se observó que algunas tiendas dominan ciertas regiones, obteniendo un rendimiento superior allí.
# * La Tienda 2 y Tienda 3 muestran mayor densidad de ventas en zonas específicas, mientras que Tienda 1 y Tienda 4 tienen menor cobertura en esas áreas.
# * Esto evidencia que la ubicación influye en el desempeño, y que las tiendas pueden adaptar estrategias de marketing y logística según su región para maximizar resultados.

# %% [markdown]
# **Conclusiones**
#
# La ubicación geográfica es un factor clave en el rendimiento de las ventas.
# Las regiones de alta concentración pueden ser estratégicas para promociones, expansión o mejora del servicio.
# Las tiendas con menor desempeño en ciertas zonas pueden necesitar optimización logística o campañas específicas.
# Este análisis proporciona información valiosa para tomar decisiones basadas en datos sobre estrategia comercial y ubicación de tiendas.

# %% [markdown]
# #**Informe Final de Análisis para Decisión de Venta**

# %% [markdown]
# ##**1. Introducción**

# %% [markdown]
# El presente informe tiene como objetivo identificar a qué tienda debería vender sus productos el Sr. Juan, basándose en un análisis detallado de cuatro tiendas distintas. Para ello, se evaluaron los siguientes factores:
#
# 1.   Ingresos totales generados por cada tienda.
# 2.   Categorías de productos más y menos vendidas.
# 3.   Calificaciones promedio otorgadas por los clientes.
# 4.   Productos con mayor y menor rotación.
# 5.   Coste de envío promedio asumido por los clientes.
#
# Este análisis permite comprender el comportamiento de venta, satisfacción del cliente y costos asociados, lo que facilita una recomendación precisa y fundamentada.

# %% [markdown]
# ##**2. Desarrollo del Analisis**

# %% [markdown]
# ###**2.1 Ingresos Totales de las Tiendas**

# %% [markdown]
# Los valores totales generados muestran la rentabilidad general de cada tienda:
#
# *  Tienda 1: 1,150,880,400.00
# *  Tienda 2: 1,116,343,500.00
# *  Tienda 3: 1,098,019,600.00
# *  Tienda 4: 1,038,375,700.00
#
# **Conclusión parcial:** La *Tienda 1* es la que más ingresos genera, lo cual sugiere un mayor volumen o mejor valorización de sus ventas. La *Tienda 4*, en cambio, presenta el menor ingreso.

# %%
fig_ingreso

# %% [markdown]
# ###**2.2 Categorías de Productos Más y Menos Vendidas**

# %% [markdown]
# El análisis de categorías evidencia qué tipo de productos tienen mayor demanda:
#
# * Tienda 1: Mayor rotación en muebles y electrodomésticos; menor demanda en accesorios pequeños.
# * Tienda 2: Alta venta de libros y productos tecnológicos; menor demanda en muebles.
# * Tienda 3: Los artículos del hogar son los más solicitados; categorías recreativas presentan menos ventas.
# * Tienda 4: Fuerte rotación en productos de dormitorio; menor salida en temática educativa.
#
# **Conclusión parcial:** Las tiendas 1 y 3 muestran una demanda más equilibrada entre categorías. La tienda 4 tiene nichos más específicos, mientras que la tienda 2 tiene alta demanda en productos muy concretos.

# %%
fig_ventas

# %% [markdown]
# ###**2.3 Calificaciones Promedio por Tienda**

# %% [markdown]
# Las calificaciones reflejan la satisfacción del cliente:
#
# * Tienda 1: 3.98
# * Tienda 2: 4.04
# * Tienda 3: 4.05
# * Tienda 4: 4.00
#
# **Conclusión parcial: **Aunque todas las tiendas mantienen buenas calificaciones, la Tienda 1 presenta el mayor nivel de satisfacción de los clientes.

# %% [markdown]
# ###**2.4 Productos Más y Menos Vendidos**

# %% [markdown]
# **Tienda 1**
# * Más vendidos: Armario, TV LED UHD 4K, Microondas (≈60 ventas)
# * Menos vendidos: Auriculares con micrófono (33 ventas)
#
# **Tienda 2**
# * Más vendido: “Iniciando en programación” (65 ventas)
# * Menos vendido: Juego de mesa (32 ventas)
#
# **Tienda 3**
# * Más vendido: Kit de bancas (57 ventas)
# *Menos vendido: Bloques de construcción (35 ventas)
#
# **Tienda 4**
# *Más vendido: Cama box (62 ventas)
# *Menos vendido: Guitarra eléctrica (33 ventas)
#
# **Conclusión parcial:** Todas las tiendas presentan un patrón estable de productos fuertes, pero la Tienda 1 destaca por tener varios productos con alto volumen de ventas, no solo uno.

# %% [markdown]
# ###**2.5 Costo de Envío Promedio**

# %% [markdown]
# Los costos de envío afectan la experiencia del cliente y la competitividad:
#
# * Tienda 1: Envío promedio: bajo-medio
# * Tienda 2: Envío promedio: medio
# * Tienda 3: Envío promedio: medio-alto
# * Tienda 4: Envío promedio: alto
#
# **Conclusión parcial:** La Tienda 1 es nuevamente la más atractiva, ya que ofrece envío de menor costo en comparación con las demás.

# %%
fig_envios

# %% [markdown]
# ##**3. Conclusión y Recomendación Final**

# %% [markdown]
# Después de analizar la situación actual de las cuatro tiendas, se evidencia que todas mantienen un desempeño aceptable. Sin embargo, dado que se está buscando una expansión hacia un nuevo emprendimiento y se desea vender una de las sucursales, se presentan las siguientes recomendaciones:
#
# 1. **Vender la Tienda 4**, ya que es la menos rentable en términos generales y no aporta el rendimiento económico esperado.
# 2. **Invertir a largo plazo en la Tienda 2**, debido a su estabilidad, buen desempeño y rentabilidad constante.
# 3. **Analizar los factores de éxito de la Tienda 1** y evaluar la viabilidad de replicarlos en las demás sucursales para mejorar su rendimiento.
# 4. **Promocionar los productos más vendidos** para atraer mayor cantidad de clientes y aumentar los ingresos, manteniendo siempre un excelente servicio al cliente en todas las tiendas.
